# %%
import pandas as pd
from os import getcwd, chdir

# %%
chdir("../../")

# %%
data_path = getcwd() + "/data/raw"

# Read the DataFrame
df = pd.read_csv(f"{data_path}/BLS_CoalMining1.csv")
# Out:
# C:\Users\nn198412\AppData\Local\Temp\ipykernel_40760\1752234432.py:4: DtypeWarning: Columns (19,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{data_path}/BLS_CoalMining1.csv")

# %%
df.iloc[1:50]
# Out:
#     AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 1     99       U.S.          1         US  221111
# 2     99       U.S.          1         US  221111
# 3     99       U.S.          1         US  221111
# 4     99       U.S.          1         US  221111
# 5     99       U.S.          1         US  221111
# 6     99       U.S.          1         US  221111
# 7     99       U.S.          1         US  221111
# 8     99       U.S.          1         US  221111
# 9     99       U.S.          1         US  221111
# 10    99       U.S.          1         US  221111
# 11    99       U.S.          1         US  221111
# 12    99       U.S.          1         US  221111
# 13    99       U.S.          1         US  221111
# 14    99       U.S.          1         US  221111
# 15    99       U.S.          1         US  221111
# 16    99       U.S.          1         US  221111
# 17    99       U.S.          1         US  221111
# 18    99       U.S.          1         US  221111
# ...
